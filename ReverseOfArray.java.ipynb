# %%
print("Hello luna, python is working")
# Out:
# Hello luna, python is working

# %%
num=i(input())
for i in range(10):
    print("Hi"+ i)
# Out:
#  5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 num=int(input())
#       2 for i in range(10):
# ----> 3     print("Hi"+ i)
#
# TypeError: can only concatenate str (not "int") to str
